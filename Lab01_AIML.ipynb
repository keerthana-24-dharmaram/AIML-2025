# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthana-24-dharmaram/AIML-2025/blob/main/Lab01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB-01:INTRODUCTION TO PYTHON,MATPLOTLIB,NUMPY

# %% [markdown]
#  Introduction to Python Packages - Numpy, Pandas Matplotlib, and Access to Data Sources

# %% [markdown]
# Part 1:Implement basic data structures using Numpy ,pandas

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
list1 = [1,2,3,4]
array1 = np.array(list1)
array1
array2 = np.array([1,2,3,4])
list1,array1,array2
# Out:
# ([1, 2, 3, 4], array([1, 2, 3, 4]), array([1, 2, 3, 4]))

# %%
## Identify the type of Data structure
type(list1) , type(array1), type(array2)
# Out:
# (list, numpy.ndarray, numpy.ndarray)

# %%
## Perform Mathematical operations on arrays ,lists
print("Adding of two arrays :", array1 + array2)
print("Subtracting of two arrays:", array1-array2)
print("Multiplying of two arrays:", array1 * array2)
print("Dividing  of two arrays:" ,array1/array2)
print("Exponentiating of two arrays:", array1**array2)
print("Multiply of array to list:", array2*list1)
# Out:
# Adding of two arrays : [2 4 6 8]
# Subtracting of two arrays: [0 0 0 0]
# Multiplying of two arrays: [ 1  4  9 16]
# Dividing  of two arrays: [1. 1. 1. 1.]
# Exponentiating of two arrays: [  1   4  27 256]
# Multiply of array to list: [ 1  4  9 16]

# %%
#Find the sin, log ,log2 ,exp values
print(f"Sine value of array1:  {np.sin(array1)}" )
print(f"log value of array1 :  {np.log(array1)}")
print(f" log base 2 value of array1:  {np.log2(array1)}")
print(f" log base 10 value of array1: {np.log10(array1)}")
print(f"exponential value of array1 : {np.exp(array1)}")
# Out:
# Sine value of array1:  [ 0.84147098  0.90929743  0.14112001 -0.7568025 ]
# log value of array1 :  [0.         0.69314718 1.09861229 1.38629436]
#  log base 2 value of array1:  [0.        1.        1.5849625 2.       ]
#  log base 10 value of array1: [0.         0.30103    0.47712125 0.60205999]
# exponential value of array1 : [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
#Create the Dataset
people =['ajay', 'varun', 'akash' ,'arun' ,'arjun']
age =[23 , 24, 25, 26, 27]
weight =[70, 71 ,72 ,73 ,74]
height=[170, 171, 172, 173, 174]

# %%
#Find the relationship between weight to height
#Generate a scatter plot to visualize the realtionship
plt.scatter(weight , height)
plt.xlabel('weight')
plt.ylabel('height')
plt.title('weight vs height')
plt.show()

# %%
#generate the bar chart for people to their weight
plt.figure(figsize=(5,4))
plt.bar(people, weight)
plt.xlabel('people')
plt.ylabel('weight')
plt.title('people vs weight')
plt.show()

# %%
#Generate the Histrogram between people Weight
plt.figure(figsize=(5,4))
plt.hist(age , alpha=0.75 , color = 'red', bins=3)
plt.xlabel('Age')
plt.ylabel('Height')
plt.title('Age vs Height')
plt.show()
